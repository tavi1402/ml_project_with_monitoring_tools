# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("data/Dataset.csv")
df.head()
# Out:
# C:\Users\any\AppData\Local\Temp\ipykernel_8564\381549638.py:1: DtypeWarning: Columns (1,7,8,16,17,18,19,20,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Dataset.csv")
#          ID Client_Income  Car_Owned  Bike_Owned  Active_Loan  House_Own  \
# 0  12142509          6750        0.0         0.0          1.0        0.0
# 1  12138936         20250        1.0         0.0          1.0        NaN
# 2  12181264         18000        0.0         0.0          1.0        0.0
# 3  12188929         15750        0.0         0.0          1.0        1.0
# 4  12133385         33750        1.0         0.0          1.0        0.0
#
#    Child_Count Credit_Amount Loan_Annuity Accompany_Client  ...  \
# 0          0.0      61190.55      3416.85            Alone  ...
# 1          0.0         15282      1826.55            Alone  ...
# 2          1.0      59527.35       2788.2            Alone  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               118249 non-null  object
#  2   Car_Owned                   118275 non-null  float64
#  3   Bike_Owned                  118232 non-null  float64
#  4   Active_Loan                 118221 non-null  float64
#  5   House_Own                   118195 non-null  float64
#  6   Child_Count                 118218 non-null  float64
#  7   Credit_Amount               118224 non-null  object
#  8   Loan_Annuity                117044 non-null  object
#  9   Accompany_Client            120110 non-null  object
#  10  Client_Income_Type          118155 non-null  object
#  11  Client_Education            118211 non-null  object
# ...

# %%
df.describe()
# Out:
#        Client_Income  Credit_Amount  Loan_Annuity  Population_Region_Relative  \
# count   9.381600e+04   93831.000000  92863.000000                92808.000000
# mean    1.757877e+04   61311.232968   2794.207912                    0.020475
# std     1.212303e+04   40718.597038   1480.520310                    0.012550
# min     2.565000e+03    4500.000000    218.700000                    0.000533
# 25%     1.125000e+04   27861.300000   1713.600000                    0.010006
# 50%     1.575000e+04   52128.000000   2596.950000                    0.018850
# 75%     2.115000e+04   83404.800000   3568.500000                    0.028663
# max     1.800009e+06  405000.000000  22500.000000                    0.056648
#
#            Age_Days  Employed_Days  Registration_Days       ID_Days  \
# count  93837.000000   96702.000000       93824.000000  91994.000000
# mean   14739.722785    2333.158425        4619.606423   2789.519099
# ...

# %%
# Identify categorical and numerical columns using conditions
categorical_columns = df.columns[df.dtypes == 'object']
numerical_columns = df.columns[df.dtypes != 'object']

# %%
categorical_columns
# Out:
# Index(['Car_Owned', 'Active_Loan', 'Client_Income_Type', 'Client_Education',
#        'Client_Marital_Status', 'Client_Gender', 'Loan_Contract_Type',
#        'Client_Housing_Type', 'Homephone_Tag', 'Workphone_Working',
#        'Client_Occupation', 'Client_Permanent_Match_Tag',
#        'Client_Contact_Work_Tag', 'Type_Organization'],
#       dtype='object')

# %%
numerical_columns
# Out:
# Index(['Client_Income', 'Credit_Amount', 'Loan_Annuity',
#        'Population_Region_Relative', 'Age_Days', 'Employed_Days',
#        'Registration_Days', 'ID_Days', 'Cleint_City_Rating', 'Score_Source_2',
#        'Score_Source_3', 'Phone_Change', 'Default'],
#       dtype='object')

# %%
numeric_issues = {}

for col in numerical_columns:
    try:
        df[col].astype(float)
    except ValueError as e:
        numeric_issues[col] = str(e)

numeric_issues
# Out:
# {}

# %%
for col in columns_to_clean:
    data[col] = data[col].str.replace('$', '').str.replace('&', '').str.replace('@', '').str.replace('x', '').astype(float)

# %%
# Initialize the imputer
imputer = SimpleImputer(strategy='mean')

# Fit the imputer and transform the data
imputer.fit_transform(df[numerical_columns])
# Out:
# array([[6.75000000e+03, 6.11905500e+04, 3.41685000e+03, ...,
#         5.00118433e-01, 6.30000000e+01, 0.00000000e+00],
#        [2.02500000e+04, 1.52820000e+04, 1.82655000e+03, ...,
#         5.00118433e-01, 9.69252923e+02, 0.00000000e+00],
#        [1.80000000e+04, 5.95273500e+04, 2.78820000e+03, ...,
#         3.29655054e-01, 2.77000000e+02, 0.00000000e+00],
#        ...,
#        [8.10000000e+03, 5.51079000e+04, 2.98935000e+03, ...,
#         5.00118433e-01, 0.00000000e+00, 0.00000000e+00],
#        [3.82500000e+04, 4.50000000e+04, 2.71935000e+03, ...,
#         7.74985460e-02, 0.00000000e+00, 0.00000000e+00],
#        [9.00000000e+03, 6.24289500e+04, 4.20165000e+03, ...,
#         2.98594990e-01, 8.05000000e+02, 0.00000000e+00]])

# %%
df1 = df.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32779 entries, 3 to 96701
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Client_Income               32779 non-null  float64
#  1   Car_Owned                   32779 non-null  object
#  2   Active_Loan                 32779 non-null  object
#  3   Credit_Amount               32779 non-null  float64
#  4   Loan_Annuity                32779 non-null  float64
#  5   Client_Income_Type          32779 non-null  object
#  6   Client_Education            32779 non-null  object
#  7   Client_Marital_Status       32779 non-null  object
#  8   Client_Gender               32779 non-null  object
#  9   Loan_Contract_Type          32779 non-null  object
#  10  Client_Housing_Type         32779 non-null  object
#  11  Population_Region_Relative  32779 non-null  float64
#  12  Age_Days                    32779 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Client_Income', 'Car_Owned', 'Active_Loan', 'Credit_Amount',
#        'Loan_Annuity', 'Client_Income_Type', 'Client_Education',
#        'Client_Marital_Status', 'Client_Gender', 'Loan_Contract_Type',
#        'Client_Housing_Type', 'Population_Region_Relative', 'Age_Days',
#        'Employed_Days', 'Registration_Days', 'ID_Days', 'Homephone_Tag',
#        'Workphone_Working', 'Client_Occupation', 'Cleint_City_Rating',
#        'Client_Permanent_Match_Tag', 'Client_Contact_Work_Tag',
#        'Type_Organization', 'Score_Source_2', 'Score_Source_3', 'Phone_Change',
#        'Default'],
#       dtype='object')

# %%
for column in df.columns:
    print(df[column].unique())
# Out:
# [ 6750.   20250.   18000.   ...  9764.1  21105.   12840.75]
# ['No' 'Yes' nan]
# ['Yes' 'No' nan]
# [ 61190.55  15282.    59527.35 ...  55224.9  166316.4  231591.6 ]
# [3416.85 1826.55 2788.2  ... 5411.7  2515.5  2989.35]
# ['Commercial' 'Service' 'Govt Job' nan 'Student' 'Maternity leave'
#  'Retired' 'Businessman']
# ['Secondary' 'Graduation' 'Graduation dropout' nan 'Junior secondary'
#  'Post Grad']
# ['M' 'W' 'S' nan 'D']
# ['Male' 'Female' nan]
# ['CL' 'RL' nan]
# ['Home' 'Family' 'Municipal' nan 'Rental' 'Office' 'Shared']
# [0.028663  0.008575  0.0228    0.020713  0.019101  0.006008  0.001417
#  0.018634  0.003541  0.008068  0.005144  0.04622   0.008866        nan
#  0.019689  0.032561  0.006852  0.020246  0.035792  0.010147  0.018801
#  0.00733   0.010276  0.015221  0.01452   0.018209  0.010006  0.0566485
#  0.006671  0.014464  0.018029  0.007114  0.0105    0.026392  0.008019
#  0.031329  0.008474  0.010643  0.011657  0.003069  0.022625  0.006305
# ...

# %%
for column in df.columns:
    print(f'{column} = {df[column].isnull().sum()}')
# Out:
# Client_Income = 2886
# Car_Owned = 2857
# Active_Loan = 2855
# Credit_Amount = 2871
# Loan_Annuity = 3839
# Client_Income_Type = 2877
# Client_Education = 2897
# Client_Marital_Status = 2752
# Client_Gender = 1888
# Loan_Contract_Type = 2924
# Client_Housing_Type = 2926
# Population_Region_Relative = 3894
# Age_Days = 2865
# Employed_Days = 0
# Registration_Days = 2878
# ID_Days = 4708
# Homephone_Tag = 0
# Workphone_Working = 0
# Client_Occupation = 19046
# Cleint_City_Rating = 1944
# Client_Permanent_Match_Tag = 0
# Client_Contact_Work_Tag = 0
# Type_Organization = 2850
# Score_Source_2 = 4536
# Score_Source_3 = 21285
# Phone_Change = 2867
# Default = 0
